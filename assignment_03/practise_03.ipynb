# %%
import random

for i in range(0,10):
   
   for x in range(0,10):
       print(random.randint(0,9),end = " ")
   print("\n")
# Out:
# 3 6 9 3 0 8 8 6 3 2
#
# 0 9 7 6 0 0 4 0 6 6
#
# 5 0 3 1 1 2 4 5 8 3
#
# 3 9 7 6 5 5 2 1 2 3
#
# 9 9 1 4 2 5 8 7 2 7
#
# 3 9 4 8 8 1 8 2 5 3
#
# 6 9 0 3 4 9 4 3 4 8
#
# 6 3 8 4 7 0 6 9 6 8
#
# 0 2 9 8 1 5 2 1 0 6
#
# 6 9 5 7 8 9 3 3 9 5

# %%
import random

for i in range(0,10):
    
    for y in range(0,10):
      x = random.randint(0,9)
      if ((x % 2) == 0):
        print(x,end = " ")
      else:
        print("*",end = ' ')
    print("\n")
# Out:
# * 0 * 2 * * 2 6 8 *
#
# 6 4 * 6 6 0 6 * * 6
#
# 8 8 6 * * 6 6 * * *
#
# * 4 * 8 8 6 6 6 4 *
#
# * 6 8 4 * 8 6 * 6 8
#
# 4 2 * * 0 0 2 4 2 *
#
# * * * 6 8 * 0 8 0 0
#
# * 8 0 * 8 4 8 8 6 2
#
# 2 * * * 6 * 0 0 0 *
#
# 8 2 * * 4 0 * * 6 2

# %%
import random
for i in range(0,10):
    sum=0
    for y in range(0,10):
        x=random.randint(0,9)
        print(x,end = " ")
        sum=sum+x
        if y == 9:
            print('* {total}'.format(total=sum))
    print("\n")
# Out:
# 5 8 8 9 4 6 8 3 8 6 * 65
#
#
# 7 4 6 5 2 9 1 2 3 4 * 43
#
#
# 9 0 1 5 8 7 6 9 2 4 * 51
#
#
# 2 7 3 2 6 1 9 1 4 0 * 35
#
#
# 4 2 7 2 1 1 7 5 9 3 * 41
#
#
# 6 0 6 7 9 9 5 6 2 9 * 59
#
#
# 2 6 5 1 5 4 2 8 9 0 * 42
#
#
# 3 6 7 8 6 5 6 1 0 8 * 50
#
#
# 0 6 7 2 7 1 4 6 8 1 * 42
#
#
# 4 9 7 5 2 4 9 3 1 1 * 45

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8b81c284-0093-4b0f-9c9e-a532c7444669' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
