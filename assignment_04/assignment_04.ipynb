# %%
# read all lines from census_cost to line_list
with open ("census_cost.py","rt")as f:
    line_list = f.readlines()
    line_list=[line.replace('\n',',') for line in line_list]
for row in line_list:
    print(row)
# Out:
# Source: https://www.genealogybranches.com/censuscosts.html,
# Census Year	Total Population	Census Cost	Average Cost Per Person,
# 1790	3,929,214	$44,377	1.13 cents,
# 1800	5,308,483	$66,109	1.24 cents,
# 1810	7,239,881	$178,445	2.46 cents,
# 1820	9,633,822	$208,526	2.16 cents,
# 1830	12,866,020	$378,545	2.94 cents,
# 1840	17,069,458	$833,371	4.88 cents,
# 1850	23,191,876	$1,423,351	6.14 cents,
# 1860	31,443,321	$1,969,377	6.26 cents,
# 1870	38,558,371	$3,421,198	8.87 cents,
# 1880	50,155,783	$5,790,678	11.54 cents,
# 1890	62,979,766	$11,547,127	18.33 cents,
# 1900	76,303,387	$11,854,000	15.54 cents,
# 1910	91,972,266	$15,968,000	17.07 cents,
# 1920	105,710,620	$25,117,000	23.76 cents,
# 1930	122,775,046	$40,156,000	32.71 cents,
# 1940	131,669,275	$67,527,000	51.29 cents,
# 1950	151,325,798	$91,462,000	60.44 cents,
# 1960	179,323,175	$127,934,000	71.34 cents,
# 1970	203,302,031	$247,653,000	$1.22,
# 1980	226,542,199	$1,078,488,000	$4.76,
# 1990	248,718,301	$2,492,830,000	$10.02,
# ...

# %%
top2_list = (line_list[2:4])
print(*top2_list, sep='\n')
# Out:
# 1790	3,929,214	$44,377	1.13 cents
#
# 1800	5,308,483	$66,109	1.24 cents

# %%
data_list = (line_list[4:])
print(*data_list, sep='\n')
# Out:
# 1810	7,239,881	$178,445	2.46 cents
#
# 1820	9,633,822	$208,526	2.16 cents
#
# 1830	12,866,020	$378,545	2.94 cents
#
# 1840	17,069,458	$833,371	4.88 cents
#
# 1850	23,191,876	$1,423,351	6.14 cents
#
# 1860	31,443,321	$1,969,377	6.26 cents
#
# 1870	38,558,371	$3,421,198	8.87 cents
#
# 1880	50,155,783	$5,790,678	11.54 cents
#
# 1890	62,979,766	$11,547,127	18.33 cents
#
# 1900	76,303,387	$11,854,000	15.54 cents
#
# 1910	91,972,266	$15,968,000	17.07 cents
#
# 1920	105,710,620	$25,117,000	23.76 cents
#
# 1930	122,775,046	$40,156,000	32.71 cents
#
# 1940	131,669,275	$67,527,000	51.29 cents
#
# 1950	151,325,798	$91,462,000	60.44 cents
#
# 1960	179,323,175	$127,934,000	71.34 cents
#
# 1970	203,302,031	$247,653,000	$1.22
#
# 1980	226,542,199	$1,078,488,000	$4.76
#
# 1990	248,718,301	$2,492,830,000	$10.02
#
# 2000	281,421,906	$4.5 Billion	$15.99
#
# 2010*	308,745,538	$13 Billion	$42.11

# %%
census_year = 0
year_list=[]
for x in data_list:
    year_list.append(x.split()[census_year])
f.close()
for row in year_list:
 print(row)
# Out:
# 1810
# 1820
# 1830
# 1840
# 1850
# 1860
# 1870
# 1880
# 1890
# 1900
# 1910
# 1920
# 1930
# 1940
# 1950
# 1960
# 1970
# 1980
# 1990
# 2000
# 2010*

# %%
total_population = 1
pop_list=[]
for x in data_list:
    pop_list.append(x.split()[total_population])
f.close()
for row in pop_list:
    row = row.replace(","," ")
    print(row)
# Out:
# 7 239 881
# 9 633 822
# 12 866 020
# 17 069 458
# 23 191 876
# 31 443 321
# 38 558 371
# 50 155 783
# 62 979 766
# 76 303 387
# 91 972 266
# 105 710 620
# 122 775 046
# 131 669 275
# 151 325 798
# 179 323 175
# 203 302 031
# 226 542 199
# 248 718 301
# 281 421 906
# 308 745 538

# %%
census_cost = 2
cost_list=[]
for x in data_list:
    cost_list.append(x.split()[census_cost])
f.close()
for row in cost_list:
 row = row.replace(","," " )
 row = row.replace("$"," ")
 row = row.replace("Billion","*1000000000")
 print(row)
# Out:
#  178 445
#  208 526
#  378 545
#  833 371
#  1 423 351
#  1 969 377
#  3 421 198
#  5 790 678
#  11 547 127
#  11 854 000
#  15 968 000
#  25 117 000
#  40 156 000
#  67 527 000
#  91 462 000
#  127 934 000
#  247 653 000
#  1 078 488 000
#  2 492 830 000
#  4.5
#  13

# %%
avg_cost = 3
avg_list=[]
for x in data_list:
    avg_list.append(x.split()[avg_cost])
f.close()
for row in avg_list:
 print(row)
# Out:
# 2.46
# 2.16
# 2.94
# 4.88
# 6.14
# 6.26
# 8.87
# 11.54
# 18.33
# 15.54
# 17.07
# 23.76
# 32.71
# 51.29
# 60.44
# 71.34
# $1.22
# $4.76
# $10.02
# Billion
# Billion

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=db928347-f211-47ce-84a6-bd25f9c8d897' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
